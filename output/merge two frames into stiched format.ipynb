# %%
from skimage.io import imread, imsave
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img0 = imread('DeWarp0.png')
img1 = imread('DeWarp1.png')

# %%
plt.imshow(img0)

# %%
plt.imshow(img0[:,350:,:])

# %%
img0.shape
# Out:
# (1918, 2557, 3)

# %%
import numpy as np

# %%
new = np.hstack([img0[:,350:,:], img1[:,350:,:]])
new.shape
# Out:
# (1918, 4414, 3)

# %%
plt.imshow(new)

# %%
imsave('merged.png', new)
